# %%
import pandas as pd
from rake_nltk import Rake
import json

# Load your data
data = pd.read_csv('C:/Users/apoorva reddy/Downloads/combined_table2_data_with_industry_new (2).csv')
tasks_activities = data[['Tasks', 'Detailed Work Activities']].dropna()  # Drop rows with NaN values

# Initialize Rake
r = Rake()

# Combine text from "Tasks" and "Detailed Work Activities"
all_text_combined = ' '.join(tasks_activities.apply(lambda x: ' '.join(x), axis=1))

# Extract phrases from the combined text
r.extract_keywords_from_text(all_text_combined)
global_ranked_phrases = r.get_ranked_phrases()

# Define keyword lists for each category
category_keywords = {
    'Image': [
        'photo', 'scan', 'visual', 'inspect', 'camera', 'view', 'see', 'observe', 
        'picture', 'image', 'display', 'diagram', 'color', 'illustrate', 'examine',
        'photograph', 'detect', 'look', 'screen', 'x-ray', 'viewfinder', 'microscope'
    ],
    'Alphanumeric': [
        'data', 'record', 'number', 'transaction', 'account', 'document', 'calculate', 
        'analyze', 'statistics', 'text', 'report', 'log', 'inventory', 'file', 
        'input', 'code', 'digit', 'sheet', 'count', 'figure', 'sort', 'catalog', 
        'classify', 'register', 'alphabet', 'numeric', 'balance', 'sum', 'ledger'
    ],
    'Audio': [
        'listen', 'record', 'transcribe', 'speech', 'audio', 'hear', 'sound', 'voice', 
        'music', 'interview', 'call', 'broadcast', 'microphone', 'tape', 'radio', 
        'noise', 'ring', 'echo', 'soundtrack', 'song', 'volume', 'frequency', 'audio clip',
        'podcast', 'replay', 'speak', 'recording', 'dialogue', 'conference'
    ],
    'Geographic': [
        'location', 'map', 'address', 'region', 'navigate', 'site', 'place', 'route', 
        'area', 'boundary', 'country', 'state', 'terrain', 'district', 'zone', 'vicinity', 
        'latitude', 'longitude', 'coordinate', 'survey', 'land', 'geography', 'region', 
        'navigate', 'landmark', 'compass', 'city', 'province', 'urban', 'rural', 'location data'
    ]
}

# Function to categorize a phrase based on keyword matching
def categorize_phrase(phrase, keywords):
    for category, words in keywords.items():
        if any(word in phrase.lower() for word in words):
            return category
    return None

# Categorize extracted phrases and remove duplicates
global_categories = { 'Image': set(), 'Alphanumeric': set(), 'Audio': set(), 'Geographic': set() }

for phrase in global_ranked_phrases:
    category = categorize_phrase(phrase, category_keywords)
    if category:
        global_categories[category].add(phrase)

# Convert sets back to lists for JSON serialization and output results
global_categories = {category: list(phrases) for category, phrases in global_categories.items()}
print("Extracted Keywords by Category:", json.dumps(global_categories, indent=4))

# Function to calculate DTU level based on Job Zone with increased thresholds for each data type separately
def calculate_dtu_level_for_type(text, keywords, job_zone):
    count = sum(word in text.lower() for word in keywords)
    
  # Set increased thresholds for each data type based on Job Zone
    if job_zone in [4, 5]:  # Higher preparation levels
        if count > 8:
            return "High"
        elif 4 <= count <= 8:
            return "Medium"
        else:
            return "Low"
    elif job_zone == 3:  # Medium preparation level
        if count > 10:
            return "High"
        elif 5 <= count <= 10:
            return "Medium"
        else:
            return "Low"
    else:  # Lower preparation levels (1 and 2)
        if count > 12:
            return "High"
        elif 6 <= count <= 12:
            return "Medium"
        else:
            return "Low"

# Apply the DTU calculation for each data type separately in each row
for data_type, keywords in global_categories.items():
    data[f'{data_type} DTU'] = data.apply(lambda row: calculate_dtu_level_for_type(
        str(row['Tasks']) + " " + str(row['Detailed Work Activities']), 
        keywords, 
        row['Job Zone']
    ), axis=1)

# Save the final results into a CSV file
output_path = 'C:\Users/apoorva reddy/Downloads/dtu_job_zone_results_separate.csv'
data[['Industry', 'Occupation', 'Detailed Work Activities', 'Tasks','Job Zone', 'Image DTU', 'Audio DTU', 'Alphanumeric DTU', 'Geographic DTU']].to_csv(output_path, index=False)
# Out:
# Extracted Keywords by Category: {
#     "Image": [
#         "display screen",
#         "review project plans",
#         "inspect materials",
#         "related occupations review orders",
#         "perform basic screening procedures",
#         "examine chemical",
#         "observe display screens",
#         "related occupations inspect metal",
#         "compare colors",
#         "related occupations examine shipment contents",
#         "physical inspections",
#         "specific color densities",
#         "review patients",
#         "examine photographic images",
#         "looking",
#         "organizations seeking funds",
#         "personal interviews",
#         "multimedia visual aids",
#         "related occupations examine completed work",
#         "inspect finished dies",
#         "block diagrams",
#         "examine unexposed photographic plates",
#         "monitor video displays",
#         "review employee benefit programs",
#         "review loan agreements",
#         "examine medical equipment",
#         "prepare schematic diagrams",
#         "review procedures",
#         "inspect random samples",
#         "blood pressure screening",
#         "review purchase order claims",
#         "visually examine gums",
#         "related occupations observe signal lights",
#         "scan files",
#         "patient interviews",
#         "avocational visual requirements",
#         "inspect outgoing work",
#         "examine samples",
#         "screening",
#         "interview job applicants",
#         "reviewing income",
#         "strip colors",
#         "inspect items",
#         "visual representations",
#         "inspect soiled articles",
#         "review software documentation",
#         "observe experiments",
#         "obtain optimum view",
#         "examine components",
#         "produce required images",
#         "detect malfunctions",
#         "transfer reference images",
#         "related occupations scan",
#         "supervise hearing screening programs",
#         "screen telephone calls",
#         "examine completed objects",
#         "observe color changes",
#         "interviews",
#         "review insurance policy",
#         "graphic displays",
#         "schematic diagrams",
#         "inspect parts",
#         "document images",
#         "observe equipment",
#         "observe dial indicators",
#         "illustrate maximum efficiency using drafting tools",
#         "inspect safety equipment",
#         "inspect motor vehicles",
#         "print images",
#         "reviewing current literature",
#         "create advanced digital images",
#         "examine real estate closing files",
#         "management review",
#         "viewers",
#         "reviewing scientific literature",
#         "inspect workpieces",
#         "inspect timing devices",
#         "inspect work",
#         "seen",
#         "cameras",
#         "inspect operational processes",
#         "detect unusual",
#         "phosphorimagers",
#         "using visual inspections",
#         "observe nurses",
#         "evaluate color density",
#         "detect diseases",
#         "angle views",
#         "photoresist layer",
#         "anesthetic screenings",
#         "review time sheets",
#         "inspect meals served",
#         "interview employees",
#         "breast cancer screening",
#         "imaged",
#         "interview participants",
#         "related occupations observe patients",
#         "review specifications",
#         "visually inspect products",
#         "examine invoices",
#         "related occupations examine stitched",
#         "review professional literature",
#         "fire inspections",
#         "review large projects",
#         "examine employee files",
#         "inspect textile products",
#         "chart reviews",
#         "examine shoes",
#         "related occupations interview employees",
#         "review existing electrical engineering criteria",
#         "related occupations inspect textile products",
#         "inspect completed installations",
#         "conduct interviews",
#         "discolored skin",
#         "review clients",
#         "related occupations observe woven cloth",
#         "photograph layouts",
#         "interview customers",
#         "visual hygiene",
#         "otoacoustic screening",
#         "using camera",
#         "inspect installed components",
#         "inspect electronic equipment",
#         "review company records",
#         "detect harmful microorganisms",
#         "related occupations inspect items",
#         "inspect work environments",
#         "oversee staff training",
#         "observe gauges",
#         "photocopiers",
#         "otherwise examine products",
#         "inspect electrical",
#         "medical images",
#         "screens",
#         "inspect finished products",
#         "detection",
#         "interview witnesses",
#         "review findings",
#         "reviewing patients",
#         "selection interviews",
#         "match sample colors",
#         "oversee training programs",
#         "related occupations examine",
#         "detect disease",
#         "review completed construction drawings",
#         "observe equipment operations",
#         "image files",
#         "related occupations inspect materials",
#         "coloring pigments",
#         "examiners",
#         "conduct visual field tests",
#         "illustrate material",
#         "inspect components",
#         "related occupations inspect food products",
#         "detect variations",
#         "produce layered photo masks",
#         "compliance reviews",
#         "display student work",
#         "observe equipment operation",
#         "interview results",
#         "inspect pipelines",
#         "display students",
#         "images produced",
#         "examine electronic components",
#         "inspect worn tires",
#         "reviewing records",
#         "examine medical instruments",
#         "review accuracy",
#         "related occupations examine eyes",
#         "related occupations inspect electrical",
#         "inspectors",
#         "review files",
#         "spectrophotometry techniques",
#         "examine checks",
#         "interview personnel",
#         "look",
#         "visual aids",
#         "review property damage estimates",
#         "scanning",
#         "review employee safety programs",
#         "examine finished surfaces",
#         "following wiring diagrams",
#         "specify scan sequences",
#         "inspect",
#         "seeds",
#         "inspect articles",
#         "review repair cost estimates",
#         "related occupations review technical documents",
#         "observe drilling",
#         "color charts",
#         "video screens",
#         "examine models",
#         "review license",
#         "examine patient",
#         "related occupations observe safety precautions",
#         "cleaning screens",
#         "scans",
#         "examine fetuses",
#         "examine materials",
#         "safe inspection",
#         "related occupations inspected printed materials",
#         "high speed business photocopiers",
#         "screen rulings",
#         "colored foil",
#         "observe operations inside furnaces",
#         "colors",
#         "observe packages moving along conveyors",
#         "diagnostic screenings",
#         "inspecting",
#         "related occupations examine microscopic samples",
#         "examine equipment",
#         "correct health inspection violations",
#         "observe positions",
#         "review cases",
#         "detect",
#         "displayed",
#         "detect leaks",
#         "examine job orders",
#         "visual system",
#         "photo plotting design onto film",
#         "examine products purchased",
#         "examine food trays",
#         "operate photographic developing",
#         "merchandise displays",
#         "reviewing reports",
#         "observe machines",
#         "logic diagrams",
#         "oversee business processes",
#         "inspect shipments",
#         "maintain displays",
#         "observe ultrasound display screen",
#         "performing visual inspections",
#         "interview employers",
#         "review reports",
#         "inspect material",
#         "inspection reports describing results",
#         "scanners",
#         "oversee construction",
#         "special inspections",
#         "drug screenings",
#         "examine instruments",
#         "detect faulty operation",
#         "inspect sample workpieces",
#         "inspect furnaces",
#         "transferring images",
#         "review logistics performance",
#         "detect possible malfunctions",
#         "review program specifications",
#         "overseeing contract obligations",
#         "examine financial records",
#         "observe continuous operation",
#         "examine engines",
#         "conduct exit interviews",
#         "review data obtained",
#         "inspect individual parts",
#         "interviewing individuals",
#         "examine clients",
#         "inspect cash reserves",
#         "observe",
#         "inspect production equipment",
#         "using image",
#         "examine gums",
#         "detected",
#         "images",
#         "inspections",
#         "microscopes",
#         "review research literature",
#         "examine workpieces",
#         "preparing merchandise displays",
#         "inspect metal",
#         "examine finished plates",
#         "detect problems",
#         "using diagrams",
#         "observe work",
#         "inspect production processes",
#         "detect abnormalities",
#         "inspect property",
#         "seepage",
#         "facilities inspections",
#         "mri ), single photon emission computed tomography",
#         "review electrical engineering plans",
#         "detect deviations",
#         "observe meters",
#         "observe bobbins",
#         "determine visual acuity",
#         "examine documents",
#         "create diagrams",
#         "color schemes",
#         "inspect bundle packaging",
#         "visually inspect equipment",
#         "review plans",
#         "original colors",
#         "detect processing defects",
#         "inspect chains",
#         "review violations",
#         "inspect machined parts",
#         "diagrams",
#         "review schematics",
#         "laser camera",
#         "color blindness",
#         "review art",
#         "using interviews",
#         "detect equipment malfunctions",
#         "related occupations operate photographic developing",
#         "review applications",
#         "interviewed",
#         "completing mechanical inspections",
#         "restore natural color",
#         "related occupations interview clients",
#         "perform periodic inspections",
#         "oversee testing",
#         "interview people",
#         "examine physical characteristics",
#         "examine furniture frames",
#         "determine furniture colors",
#         "interviewing",
#         "stock product displays",
#         "review audit reports",
#         "observe objects",
#         "develop diagrams",
#         "visual displays",
#         "silkscreen printing device",
#         "inspect products",
#         "overseeing facility needs",
#         "inspect airframes",
#         "products visually",
#         "visualize",
#         "observe metal color",
#         "television viewing",
#         "align photo mask pattern",
#         "obtain desired colors",
#         "using microscopes",
#         "review daily work",
#         "observe clients",
#         "inspect electrical connections",
#         "inspect equipment",
#         "diagrams describing logical operational steps",
#         "using colored markers",
#         "displays",
#         "film image",
#         "related occupations examine completed workpieces",
#         "using magnetic resonance scanner equipment",
#         "observe temperature",
#         "bind printed images together",
#         "related occupations inspect workpieces",
#         "examine prescriptions",
#         "review correspondence",
#         "detect machine malfunctions",
#         "examine tools",
#         "oversee payroll functions",
#         "detect production problems",
#         "related occupations oversee business processes",
#         "using scanners",
#         "examine extruded products",
#         "review sales",
#         "observe students",
#         "interview",
#         "control panel displays",
#         "glucose screening",
#         "examine titles",
#         "installation diagrams",
#         "examine merchandise",
#         "related occupations inspect products",
#         "review work done",
#         "inspect medical",
#         "examine logs",
#         "screen beds",
#         "detect sounds",
#         "microbial contamination detection",
#         "review forms",
#         "additional views",
#         "oversee regional",
#         "inspect marine equipment",
#         "examine physiological",
#         "observe machine gauges",
#         "review individual",
#         "wiring diagrams",
#         "review customer insurance information",
#         "visually",
#         "camera",
#         "review work performance",
#         "specified colors",
#         "inspect aircraft components",
#         "prepare equipment inspection schedules",
#         "related occupations inspect finishes",
#         "related occupations inspect",
#         "scanner",
#         "observe action",
#         "review processing schedules",
#         "examine parts",
#         "examine metal stock",
#         "colors conform",
#         "examine trays",
#         "review accounts",
#         "color separations",
#         "review published materials",
#         "color",
#         "inspect used parts",
#         "review prescription",
#         "observe conveyor operations",
#         "coloring",
#         "review production schedules",
#         "administer screening tests",
#         "skin coloring",
#         "measure visual acuity",
#         "oversee administrative policies",
#         "review workflow charts developed",
#         "transmit images",
#         "examine electronic schematics",
#         "detect swelling",
#         "annual dermatologic screenings",
#         "review project instructions",
#         "interview new patients",
#         "examine animals",
#         "detect jams",
#         "inspect structural components",
#         "examine patients",
#         "safety inspectors",
#         "observe equipment gauges",
#         "detect defects",
#         "review blueprints",
#         "seek",
#         "inspect containers",
#         "examine engraving",
#         "views",
#         "review patient medical histories",
#         "communicable disease screening",
#         "observe air",
#         "seeing",
#         "inspect playing fields",
#         "related occupations observe",
#         "detect equipment problems",
#         "interview credit applicants",
#         "microfilm photography",
#         "pure tone screening",
#         "review final layouts",
#         "review operations",
#         "review requisition orders",
#         "review manufacturer",
#         "review details",
#         "product design reviews",
#         "examine practices",
#         "photograph certain images",
#         "magnetic inspection equipment",
#         "quantities inspected",
#         "electron microscopes",
#         "interview production",
#         "using microscope",
#         "examine work orders",
#         "review changes",
#         "examine boilers",
#         "illustrate technical reports",
#         "related occupations examine claims forms",
#         "set scanners",
#         "computer images",
#         "interview patients upon admission",
#         "inspect mechanical equipment",
#         "tables beneath camera lenses",
#         "oversee administrative procedures",
#         "inspection results",
#         "inspect machines",
#         "interview individuals",
#         "related occupations inspect finished products",
#         "interview claimants",
#         "view",
#         "related occupations review prescriptions",
#         "review operational records",
#         "review police reports",
#         "interview prospective clients",
#         "examine furniture",
#         "detect bubbles",
#         "observe flow",
#         "inspect industrial",
#         "observe patients",
#         "review operating practices",
#         "examine repair tags",
#         "using calibrated microscopes",
#         "examine individual titles",
#         "inspect facilities",
#         "examine",
#         "examine credentials",
#         "transfer image",
#         "image produced",
#         "oversee",
#         "oversee installation",
#         "observe mechanical operation",
#         "magnetic resonance images",
#         "related occupations review blueprints",
#         "reviewing invoices",
#         "related occupations inspect mechanical equipment",
#         "store suitable images",
#         "inspect stock",
#         "examine looms",
#         "observe milling",
#         "including skin color",
#         "interconnection diagrams",
#         "review records",
#         "examine objects",
#         "observe operations",
#         "inspect mechanical components",
#         "inspect garments",
#         "video cameras",
#         "reviewing",
#         "inspection",
#         "immittance screening",
#         "related occupations inspect mechanical components",
#         "inspecting malfunctioning",
#         "detect symptoms",
#         "examine damaged vehicle",
#         "conduct detailed bill reviews",
#         "detect potential problems",
#         "detect flaws",
#         "observe tests",
#         "review work requests",
#         "review material",
#         "inspect mail machine output",
#         "inspecting drives",
#         "examine claims investigated",
#         "examine designs",
#         "related occupations inspect shipments",
#         "inspect sterile",
#         "review physician",
#         "related occupations inspect food processing areas",
#         "positron emission tomography scans",
#         "review project requests describing database user needs",
#         "reviewing proposals",
#         "related occupations observe screen",
#         "review balance sheets",
#         "inspect specified areas",
#         "review work orders",
#         "using television screens",
#         "observed",
#         "interview loan applicants",
#         "review garment magazines",
#         "scan patients",
#         "detect indications",
#         "examine teeth",
#         "examine information",
#         "inspect fire suppression systems",
#         "interview patients",
#         "inspect meat products",
#         "trajectory visualization",
#         "related occupations observe operation",
#         "interview techniques",
#         "retailers regarding product displays",
#         "review operational reports",
#         "photos",
#         "review technical documents",
#         "detect surface defects",
#         "review invoices",
#         "examine assembled",
#         "detect jamming",
#         "inspect operating units",
#         "examine products",
#         "visual materials",
#         "photographs",
#         "related occupations review license",
#         "operate digital picture archiving communications systems",
#         "select photographs",
#         "display",
#         "inspect lens blanks",
#         "review insurance policy terms",
#         "inspect galley equipment",
#         "review employment applications",
#         "visual",
#         "oversee departmental budget",
#         "observe machine operation",
#         "related occupations examine documents",
#         "inspect finishes",
#         "inspection information",
#         "visualizations",
#         "related occupations interview patients",
#         "inspect work areas",
#         "observe operation",
#         "review collection reports",
#         "inspected printed materials",
#         "review resource needs",
#         "oversee operation",
#         "examine raw woodstock",
#         "inspect work sites",
#         "color drawings",
#         "exchange views",
#         "review existing manufacturing processes",
#         "observe lights",
#         "interview clients individually",
#         "review service plans",
#         "related occupations inspect work environments",
#         "observe machine operations",
#         "computer screen formats",
#         "inspect vats",
#         "observe individuals",
#         "examine sketches",
#         "photograph treated area",
#         "metal color",
#         "examine molds",
#         "sightseeing",
#         "conduct screening interviews",
#         "observe environmental problems",
#         "detect health problems",
#         "oversee medicaid",
#         "reviewing configuration files",
#         "review medical records",
#         "related occupations inspect equipment",
#         "review compiled data",
#         "review patient progress",
#         "related occupations inspect completed work",
#         "locate color imperfections",
#         "screen",
#         "oversee equipment start",
#         "match color specifications",
#         "observe job performance",
#         "review purchasing files",
#         "review",
#         "inspect pulleys",
#         "examine characteristics",
#         "display statistics",
#         "examine city directories",
#         "computer displays",
#         "scan",
#         "examine finished workpieces",
#         "review patient information",
#         "review new product plans",
#         "generate new images",
#         "inspect systems",
#         "diagnostic images",
#         "inspect coated",
#         "oversee recording",
#         "examine sample garments",
#         "inspect images",
#         "produce photographic",
#         "review laboratory test reports",
#         "detect weaving defects",
#         "examine springs",
#         "related occupations examine patients",
#         "help interviewees",
#         "examine condition",
#         "arrange displays",
#         "oversee day",
#         "inspect physical conditions",
#         "review work",
#         "create images",
#         "interviewees",
#         "display placement",
#         "diabetes screenings",
#         "review documents",
#         "image",
#         "oversee project production efforts",
#         "interview officials",
#         "examine mouth",
#         "inspect condition",
#         "examine blueprints",
#         "interview clients",
#         "inspect cargo areas",
#         "microscope",
#         "illustrate specified materials",
#         "inspect completed work",
#         "help physicians examine",
#         "advise licensees",
#         "oversee incorporation",
#         "related occupations inspect cargo",
#         "record images",
#         "detect workpiece defects",
#         "brighten colors",
#         "related occupations review physicians",
#         "observe color",
#         "inspect food products",
#         "medical professionals regarding image",
#         "examine product samples",
#         "review procedure requests",
#         "examine children regularly",
#         "examine letters",
#         "color pigments",
#         "inspect product load",
#         "observe production",
#         "observe precautions required",
#         "review account records",
#         "review billing",
#         "inspect dies",
#         "online screen",
#         "review customer accounts",
#         "inspect cables",
#         "using scanner keyboards",
#         "produce images",
#         "detect defective packaging",
#         "using camera unit connected",
#         "archiving computerized images",
#         "dynamic visual acuity",
#         "inspect machinery",
#         "seek substitutes",
#         "inspect lumber",
#         "related occupations inspect areas",
#         "issues involving corporate image projects",
#         "oversee public health programs",
#         "information using picture archiving",
#         "related occupations inspect etched work",
#         "related occupations examine documentation",
#         "inspect assembled vessels",
#         "inspect logs",
#         "reviewing genetics",
#         "record inspection"
#     ],
#     "Alphanumeric": [
#         "required environmental records",
#         "develop data models",
#         "analyze laboratory specimens",
#         "analyze individual cases",
#         "calculate valve areas",
#         "consumer electronics applications",
#         "balance sheets",
#         "internal reporting",
#         "filed",
#         "organizational reports",
#         "histotechnology",
#         "fasten sheet metal coverings",
#         "inventory medical supplies",
#         "related occupations maintain patient records",
#         "prepare reports regarding market conditions",
#         "shift report forms",
#         "biologists",
#         "data security",
#         "manage information technology projects",
#         "counteract adverse reactions",
#         "textures",
#         "database impacts",
#         "related occupations analyze areas",
#         "maintaining staff records",
#         "transactions",
#         "numerical order",
#         "sort defective pieces according",
#         "large troubled accounts",
#         "record patient medical histories",
#         "backlogs",
#         "current inventory",
#         "maintain operations data",
#         "personnel reports",
#         "neurological disorders including risk factors",
#         "analyze test results",
#         "trade catalogs",
#         "analyze computer printouts",
#         "report major repair needs",
#         "train medical records staff",
#         "verify application data",
#         "including accounting systems",
#         "document operational procedures",
#         "proofread documents",
#         "summaries related",
#         "evaluate patient data",
#         "sortation equipment",
#         "securities transactions",
#         "news reports",
#         "implement records management program",
#         "read worker logs",
#         "analyze jobs using observation",
#         "analyze financial",
#         "develop database architectural strategies",
#         "treat major neurological system diseases",
#         "analyze medical samples",
#         "information technology",
#         "inventory classroom equipment",
#         "report project plans",
#         "record data obtained",
#         "operational data",
#         "inventory",
#         "calculate specific material",
#         "analyze incident data",
#         "make decisions concerning inventory requirements",
#         "clinical resumes",
#         "using computer database software",
#         "related occupations analyze training needs",
#         "record details",
#         "calculate figures",
#         "sorted mail",
#         "operate textile machines",
#         "pathology staff",
#         "procedural codes",
#         "calculate numerical data",
#         "mark identifying data",
#         "manipulate data",
#         "duplicate records",
#         "record receipts",
#         "spreadsheet",
#         "update human resources documents",
#         "related occupations analyze operational",
#         "research microbiological",
#         "perform multifactor data",
#         "record temperatures",
#         "reporting",
#         "cancel accounts",
#         "train cardiology technologists",
#         "accident reports",
#         "design documentation",
#         "related occupations analyze business",
#         "code logical",
#         "log landing areas",
#         "supervisory reports",
#         "technology",
#         "process documentation",
#         "transaction documents",
#         "calculate labor",
#         "analyze financial activities",
#         "corporate logistics",
#         "write instruction sheets",
#         "communicate fundraising program data",
#         "analyze project requests",
#         "production progress reports",
#         "certificate records",
#         "related documents",
#         "narrative reports",
#         "compute transaction fees",
#         "remove clogs",
#         "record results",
#         "record new insurance policies",
#         "endocrinologist",
#         "study documentation",
#         "accommodate sheets",
#         "dimensional data",
#         "record numbers",
#         "psychologists",
#         "maintain pattern records",
#         "industrial data",
#         "prepare analytical reports",
#         "prepare management reports defining",
#         "analyze forecasting data",
#         "report maintenance",
#         "classify microorganisms",
#         "identify required data",
#         "produce medical reports",
#         "post information onto designated records",
#         "prepare medical reports",
#         "career path reports",
#         "analyze information",
#         "compute numbers",
#         "complete records",
#         "patient profiles",
#         "interpret data",
#         "archival databases",
#         "count currency",
#         "risk reports",
#         "maintain client records",
#         "complete production reports",
#         "sheet steel",
#         "evaluate data quality",
#         "analyze details",
#         "enhance database performance",
#         "computer technology",
#         "investigate green consumer electronics applications",
#         "new technologies",
#         "read documents",
#         "bed sheets",
#         "record production data",
#         "physiological processes",
#         "inventory supplies received",
#         "log",
#         "shipping documents",
#         "obtain data",
#         "record patient identification",
#         "analyze laboratory findings",
#         "document individuals",
#         "operate new office technologies",
#         "analyze geological",
#         "analyze factors",
#         "technology demonstrators",
#         "title encumbrances encountered",
#         "analyze information obtained",
#         "prepare budget reports",
#         "file documents",
#         "cardiology technologists",
#         "collecting data",
#         "maintain social services program records",
#         "evaluate statistical data",
#         "diagnostic radiology",
#         "analyze test data",
#         "analyze financial data",
#         "analyze samples",
#         "related occupations calculate clients",
#         "digital",
#         "tumor registry data",
#         "morphological change",
#         "analyze test information",
#         "supervise audiology students",
#         "consumer preferences",
#         "time sheets",
#         "record prototype test results",
#         "implement research methodology",
#         "record operating data",
#         "accounting records",
#         "maintain call records",
#         "analyze market conditions",
#         "record mill production",
#         "related occupations analyze project data",
#         "submit case reports",
#         "prepare required reports",
#         "related occupations analyze health",
#         "mortgage transactions",
#         "number",
#         "prepare administrative documents",
#         "database management",
#         "stability data",
#         "hospital records",
#         "recording errors",
#         "data dictionary",
#         "analyze market",
#         "payroll data",
#         "pathological areas",
#         "analyze",
#         "safety codes",
#         "ledgers",
#         "edit documents",
#         "attach physiological monitoring leads",
#         "complete billing documents",
#         "internet technology",
#         "prepare research reports",
#         "analyze project data",
#         "prepare proposal documents",
#         "consumption reports",
#         "procedure reports",
#         "record lens power",
#         "write reports",
#         "reliability data",
#         "laser technology",
#         "repair textiles",
#         "keeping sales records",
#         "program computerized numerical control machine tools",
#         "assemble documentation packages",
#         "file grooves",
#         "accounting services",
#         "maintain student records",
#         "record repairs",
#         "record sales",
#         "complete student records",
#         "record operational information",
#         "locate files relating",
#         "record measures",
#         "coordinate inventory",
#         "submitting discrepancy reports",
#         "prepare reports summarizing patient diagnostic",
#         "analyze financial records",
#         "outstanding balances",
#         "test green technologies",
#         "balance cash",
#         "cytotechnology",
#         "specify inputs accessed",
#         "safety records",
#         "record information",
#         "file related forms",
#         "prepare statistical reports",
#         "balance problems",
#         "weigh log trucks",
#         "existing data",
#         "molecular biology",
#         "daily production records",
#         "file records",
#         "code data",
#         "productivity reports",
#         "record weights",
#         "plastic sheet",
#         "employment records",
#         "computer numerically controlled machine tools",
#         "record treatment given",
#         "document testing",
#         "specified production reports",
#         "write operational reports",
#         "examination records",
#         "record settings",
#         "record use",
#         "clarify codes",
#         "validation reports",
#         "sheet",
#         "sort items",
#         "current file",
#         "following daily international rate sheets",
#         "related occupations analyze information",
#         "evaluate data processing proposals",
#         "calculate draft space",
#         "analyze reference materials",
#         "record personnel information",
#         "maintain medical files",
#         "production technology",
#         "physiological attributes",
#         "record minutes",
#         "classify organisms based",
#         "truck load numbers",
#         "record medical",
#         "create technology",
#         "classify excess",
#         "prepare documents",
#         "databases",
#         "customer service logs",
#         "assigned accounts",
#         "billing data",
#         "analyze operational",
#         "analyze biological samples",
#         "radiologic staff",
#         "generic database structure",
#         "related occupations prepare reports summarizing patient diagnostic",
#         "accounting department",
#         "inventory levels",
#         "using stock records",
#         "using hand files",
#         "keeping financial records",
#         "maintain repair logs",
#         "data files",
#         "select files",
#         "retrieve data",
#         "record accurate patient history",
#         "implementing green building technologies",
#         "store records",
#         "consumption",
#         "bank account records",
#         "geographical data",
#         "log books",
#         "digital circuitry",
#         "cost reports",
#         "prepare periodic reports",
#         "maintain equipment service records",
#         "previous record",
#         "radiologic",
#         "prepare biological specimens",
#         "maintaining files",
#         "using polyethylene sheets",
#         "diagnose neurological conditions based",
#         "operate mechanized files",
#         "develop sustainable manufacturing technologies",
#         "log markers",
#         "maintaining documents",
#         "maintain system logs",
#         "fund epidemiologic research",
#         "written reports",
#         "calculate doses",
#         "combustion analyzers",
#         "physical database descriptions",
#         "necessary documentation",
#         "report incidences",
#         "pay records",
#         "properly recorded",
#         "manipulate raw data using statistical software",
#         "company documents",
#         "geiger counters",
#         "report unusual behavior",
#         "maintain personnel related documentation",
#         "customer related data",
#         "textile processing",
#         "inventory control",
#         "calculate daily transactions",
#         "savings data",
#         "serving counters",
#         "develop data models describing data elements",
#         "using files",
#         "perform textile processing",
#         "attach appropriate files",
#         "parts catalogs",
#         "related statistics",
#         "analyze statistical information",
#         "encode",
#         "input initial part dimensions",
#         "compute data",
#         "biological hazards",
#         "charge account plates",
#         "statistics",
#         "optical data storage devices",
#         "discharge summaries",
#         "related occupations analyze product failure data",
#         "keep records pertaining",
#         "record transactions",
#         "ophthalmologist",
#         "complete blood counts",
#         "neurology",
#         "record sterilizer test results",
#         "operate cash registers",
#         "compare encoded tapes",
#         "detailed reports",
#         "sortation stations",
#         "record training activities",
#         "commercial customer files",
#         "record patient medical data",
#         "related occupations record patient medical histories",
#         "related occupations collect biological specimens",
#         "physiological responses",
#         "perform data entry",
#         "maintenance records",
#         "database parameters",
#         "deposit accounts",
#         "report incidents",
#         "report defective equipment",
#         "technological innovations",
#         "context",
#         "recording address changes",
#         "public records",
#         "direct log movement",
#         "related occupations analyze test data",
#         "document technical design details",
#         "sheet metal products",
#         "grade logs according",
#         "new accounts",
#         "conduct psychological research",
#         "coordinate radiological services",
#         "document",
#         "summarize job analysis",
#         "worksheets",
#         "maintain medical records",
#         "checking neurological reflexes",
#         "records concerning costs",
#         "related occupations maintain client records",
#         "calculate costs",
#         "data analysis",
#         "technological advances",
#         "count daily inventories",
#         "appropriate number",
#         "cut required number",
#         "collect biological specimens",
#         "provide dermatologic consultation",
#         "consumer protection laws",
#         "tainted digital transfers",
#         "dictated reports",
#         "related documentation",
#         "data charts",
#         "analyze market research data",
#         "text",
#         "analyzing data",
#         "enter account information",
#         "prepare written documents",
#         "cardiologist",
#         "document database architectures",
#         "compile data pertinent",
#         "balance",
#         "measure felled logs",
#         "recording information",
#         "handwritten medical records",
#         "record operational details",
#         "repairing logging",
#         "coordinate neurological services",
#         "data processing",
#         "marketing data",
#         "subordinate radiotherapy technologists",
#         "update donor databases",
#         "record applications",
#         "document computer security",
#         "green technology",
#         "inventory reports",
#         "record height",
#         "keep accurate records",
#         "report delays",
#         "balance period",
#         "record gauge readings",
#         "consumers",
#         "manufacturing batch records",
#         "search files",
#         "interpret statistical data related",
#         "prepare data",
#         "calculate required capacities",
#         "radiology patients",
#         "prepare reports detailing student activities",
#         "reporting agencies",
#         "oncology",
#         "company logos",
#         "data using statistical software",
#         "code film",
#         "file master copies",
#         "evaluate new technologies",
#         "database management system software",
#         "alter text size",
#         "search records",
#         "interpret flight test data",
#         "keeping records",
#         "issue documentation",
#         "recording",
#         "conduct standardized biological",
#         "analyze malfunctions",
#         "analyze medical data",
#         "database systems",
#         "biological processes",
#         "new green technologies",
#         "type documents",
#         "assess database performance",
#         "technical data",
#         "balance scales",
#         "maintain equipment logs",
#         "computer databases",
#         "report findings",
#         "closing documents",
#         "process data",
#         "obtaining valid data",
#         "including documentation",
#         "process transactions",
#         "transactional data",
#         "digital information",
#         "maintain inventory",
#         "following documentation",
#         "delineate technology",
#         "document standard",
#         "maintain records",
#         "prepare reports summarizing daily transactions",
#         "customizing commercial databases",
#         "automated teller transactions",
#         "related occupations analyze chemical compounds",
#         "records control",
#         "evaluate data",
#         "process textile goods",
#         "gynecological care",
#         "file data",
#         "documentation",
#         "related occupations record information",
#         "jab logs",
#         "support document",
#         "behavioral neurology",
#         "neurological diagnostic",
#         "identification numbers",
#         "county regulations",
#         "loan files",
#         "sales records",
#         "recording instruments",
#         "analyze quantitative data",
#         "count articles removed",
#         "recording production",
#         "physiology",
#         "record grade",
#         "discuss account status",
#         "gather financial records",
#         "client records",
#         "maintain customer records",
#         "survey sheets",
#         "operative reports",
#         "technical source data necessary",
#         "requested transactions",
#         "coordinating financial reporting",
#         "recommend data",
#         "research data",
#         "product numbers",
#         "analyze information processing",
#         "classify",
#         "neurological problems",
#         "calculate machine speed",
#         "calculate",
#         "validation data",
#         "principal sum",
#         "retrieve patient medical records",
#         "pathology",
#         "direct nuclear medicine technologists",
#         "prepare written documentation",
#         "health care facility records",
#         "write pathology reports summarizing analyses",
#         "submit reports",
#         "ophthalmologic services",
#         "report demonstration",
#         "document route",
#         "treat patients using psychological therapies",
#         "sort materials",
#         "update payroll records",
#         "financial award candidates using electronic databases",
#         "psychological",
#         "record client progress",
#         "analyze specifications",
#         "produce reports",
#         "related occupations record patients",
#         "logic",
#         "inputting concise yet sufficient file documentation",
#         "maintain medical facility records",
#         "maintain cardiology equipment",
#         "record production output",
#         "computer numerically controlled cutting devices",
#         "record parts",
#         "record amounts due",
#         "proofreading documents",
#         "data processing technology",
#         "medical technology",
#         "lens analyzers",
#         "related occupations analyze laboratory specimens",
#         "data processing projects",
#         "statistical reports",
#         "terminology",
#         "accountants",
#         "define data requirements",
#         "document security transactions",
#         "analyze impact",
#         "record times",
#         "provide documentation",
#         "prepare procedural documents",
#         "maintain production reports",
#         "record client progress according",
#         "perform various data entry",
#         "classify information according",
#         "maintain loan records",
#         "write computer programming code",
#         "neurological diagnoses",
#         "transactions data",
#         "code patient data",
#         "record data",
#         "rays ), microbiologic tests",
#         "test data",
#         "offer documents",
#         "file athlete insurance claims",
#         "compile reports",
#         "document test results",
#         "count finished products",
#         "perform foreign currency transactions",
#         "nutritionally balanced",
#         "payroll accounts",
#         "related occupations maintain updated client records",
#         "loan documentation",
#         "record repairs required",
#         "related occupations calculate data",
#         "cpus ), support logic",
#         "submit data",
#         "psychological competence",
#         "numerically controlled machine tools",
#         "product technologies",
#         "counter",
#         "record records",
#         "troubleshoot pharmacy information databases",
#         "maintaining prescription records",
#         "prepare records",
#         "analyze organizational",
#         "maintaining records",
#         "analyze engineering designs",
#         "analyze business",
#         "analyze genetic information",
#         "prepare management reports",
#         "analyze chemical compounds",
#         "balance currency",
#         "collect data",
#         "radiologist",
#         "sheet insulation",
#         "data partitions",
#         "textbooks",
#         "including records",
#         "reconcile records",
#         "documenting",
#         "develop biological research methods",
#         "dermatological conditions",
#         "biological specimens",
#         "document condition",
#         "numerical control sequences",
#         "using reference files",
#         "document operational activities",
#         "analyze new",
#         "inventory data",
#         "create databases",
#         "overdue accounts",
#         "reporting back",
#         "developing new accounts",
#         "patient records",
#         "biological macromolecules",
#         "discharge documents",
#         "gross pathology",
#         "edit transcribed reports",
#         "counteract reactions",
#         "prepare technical reports",
#         "related occupations analyze blueprints",
#         "calculate test result values",
#         "reporting quality",
#         "audiologist",
#         "attach records",
#         "record specifications",
#         "monitor overdue accounts",
#         "document account activities",
#         "microbiology",
#         "technology trends",
#         "resolve account problems",
#         "reduce sheet metal sections",
#         "evaluate technical data",
#         "account information",
#         "inventory equipment",
#         "document results",
#         "texture",
#         "data analysis using specialized software",
#         "sorting bins",
#         "develop accredited psychological service programs",
#         "write research reports",
#         "computer data access needs",
#         "credit transactions",
#         "ecological",
#         "attendance records",
#         "hardware technologies",
#         "account records",
#         "interpret test data",
#         "medical records department",
#         "report production costs",
#         "warehouse records",
#         "report observations",
#         "deliver technology",
#         "operate digital imaging equipment",
#         "place textile goods",
#         "record messages",
#         "material safety data sheets",
#         "data relative",
#         "textile goods",
#         "using computer spreadsheets",
#         "relay account information",
#         "compile operating data",
#         "write detailed consultation reports",
#         "registered",
#         "input data",
#         "analyze applicants",
#         "county surveyors",
#         "compare logic element configuration",
#         "count products",
#         "maintain data",
#         "document software defects",
#         "reporting formats required",
#         "preparing documents",
#         "maximum number",
#         "sort forestry",
#         "psychological tests",
#         "report overpayments",
#         "wind specified numbers",
#         "telephone numbers",
#         "physiological testing procedures",
#         "complete appropriate documentation",
#         "correct number",
#         "record amounts",
#         "benefits accounts",
#         "test result data",
#         "analyze financial information",
#         "radiologic patients",
#         "file pieces",
#         "analyze incoming memos",
#         "collect historical cost data",
#         "individual customer accounts",
#         "language pathologists",
#         "utilize consultation data",
#         "radiation oncology team",
#         "operational reports",
#         "analyze industry trends",
#         "accompanying technical documents",
#         "code pieces",
#         "technologies",
#         "record product",
#         "operate textile cutting",
#         "ensure cash balances",
#         "code results",
#         "collect data regarding potential hazards",
#         "document test procedures",
#         "maintain necessary records",
#         "monitor current reports",
#         "update databases",
#         "apply information technology",
#         "record quantities",
#         "verify data",
#         "financial transactions",
#         "document technical specifications",
#         "analyze employment",
#         "record operational",
#         "classify products",
#         "financial data",
#         "aerospace technology",
#         "proper medical terminology",
# ...
#         "attending conferences",
#         "engineering personnel regarding details",
#         "ordering repairs",
#         "measuring instruments",
#         "generate computer tapes",
#         "claims requiring litigation",
#         "manufacturing personnel",
#         "including volume",
#         "transferring procedures",
#         "preparing nutrition recommendations",
#         "copyright infringement",
#         "manufacturing process",
#         "ensuring appropriate matches",
#         "radiopharmaceuticals received",
#         "referring callers",
#         "taper",
#         "transcribe spoken",
#         "invoices",
#         "assistance entering",
#         "speak",
#         "manufacturing",
#         "electronically controlled units",
#         "prepare stock radiopharmaceuticals",
#         "child rearing",
#         "manufacturing capabilities",
#         "claims requiring detailed analysis",
#         "transferring",
#         "securing confidential materials",
#         "measuring containers",
#         "court hearings",
#         "ultrasound equipment",
#         "ultrasound",
#         "referring patients",
#         "preparing supplies",
#         "syringes",
#         "test patient hearing",
#         "hearing protection",
#         "listen",
#         "conference attendance",
#         "stirring",
#         "hazardous condition monitoring",
#         "harsh voice problems",
#         "gain advice regarding environmentally sound",
#         "biomanufacturing personnel",
#         "explain engineering drawings",
#         "noise",
#         "service offerings",
#         "pouring plaster",
#         "administering immunizations",
#         "conferring",
#         "hiring activities",
#         "power shears",
#         "bring impurities",
#         "radioactive nuclei",
#         "enhanced radiographs",
#         "transferring patient"
#     ],
#     "Geographic": [
#         "replace defective blades",
#         "coordinate business operations",
#         "appropriate mill sites",
#         "addresses",
#         "external company web sites",
#         "installing replacement parts",
#         "coordinate personnel recruitment activities",
#         "place plated",
#         "functional statements",
#         "coordinate activities",
#         "clean work area",
#         "mark areas",
#         "order replacement parts",
#         "prepare itemized statements",
#         "parasites",
#         "coordinate implementation",
#         "coordinate work",
#         "relocation service",
#         "space allocation",
#         "conduct field surveys",
#         "prepare treatment areas",
#         "proposed sites",
#         "conduct opinion surveys",
#         "determine whether land",
#         "efficient routes",
#         "district",
#         "electricity",
#         "mask areas",
#         "surveys",
#         "related occupations clean work areas",
#         "design surveys",
#         "place shoes",
#         "hazardous waste site investigations",
#         "replace non",
#         "coordinate legal schedules",
#         "access work areas",
#         "replace worn dies",
#         "read maps",
#         "public address",
#         "placement",
#         "coordinate counseling services",
#         "replace cables",
#         "related occupations replace defective parts",
#         "address employee relations issues",
#         "state laws governing vehicle operation",
#         "replace malfunctioning components",
#         "place spools",
#         "state laws",
#         "interpret survey questions",
#         "maintain plasticity",
#         "brownfield sites",
#         "replace supplies",
#         "reception area",
#         "sandblast exposed areas",
#         "production areas",
#         "patrol work areas",
#         "coordinate established courses",
#         "replace damaged equipment",
#         "installation sites",
#         "clean food preparation areas",
#         "donation web sites",
#         "functional capacity",
#         "wash work areas",
#         "make replacement coils",
#         "measure glandular activity",
#         "work areas",
#         "coordinate workers involved",
#         "referral sites",
#         "including areas visited",
#         "capacity",
#         "area",
#         "related occupations conduct opinion surveys",
#         "coordinate installations",
#         "related web sites",
#         "survey workers",
#         "sanding rough areas",
#         "mold areas",
#         "dining areas",
#         "areas around scale houses",
#         "disposal areas",
#         "place rolls",
#         "replace automobile upholstery",
#         "coordinate project activity",
#         "polish smoothed areas",
#         "routes",
#         "place tooth models",
#         "place woodstock",
#         "coordinate repair",
#         "site fabrication shop prior",
#         "site observation",
#         "surface areas",
#         "coordinate production",
#         "addressing machines",
#         "place",
#         "related occupations place food servings",
#         "replace units",
#         "address",
#         "evaluate placement adequacy",
#         "replace parts",
#         "location",
#         "coordinate efforts",
#         "state authorities",
#         "designated areas according",
#         "compare previously prepared bank statements",
#         "place patterns",
#         "geographic locations",
#         "static electricity",
#         "implement individualized treatment plans addressing family relationship problems",
#         "access areas",
#         "coordinate project activities",
#         "place bobbins",
#         "replace worn equipment components",
#         "address smoking",
#         "toxicity",
#         "mail customer statements",
#         "operative site",
#         "coordinate operations",
#         "construction sites",
#         "coordinate software",
#         "place patients",
#         "enter coordinates",
#         "replace equipment components",
#         "replace linings",
#         "list addresses",
#         "field location",
#         "job placement",
#         "specialty areas",
#         "coordinate transportation",
#         "coordinate infection control programs",
#         "workpiece placement",
#         "coordinate administration",
#         "route",
#         "placements",
#         "address special nutrition needs",
#         "place orders",
#         "ensure correct placement",
#         "facial regions",
#         "replace",
#         "surrounding areas",
#         "nephrostomy catheter placement",
#         "mail charge statements",
#         "maps",
#         "land reclamation projects",
#         "coordinate treatment",
#         "required locations",
#         "displacement",
#         "ensure car placement accuracy based",
#         "landscaping",
#         "replace ocular tissue",
#         "replace broken",
#         "web site",
#         "coordinate worker training",
#         "ventilation surveys",
#         "commercial surveys",
#         "determine state",
#         "state health agencies",
#         "coordinate shutdowns",
#         "state regulations",
#         "activity areas",
#         "replace light bulbs",
#         "mailing monthly statements",
#         "explain survey objectives",
#         "determine allocations",
#         "visit sites",
#         "regularly scheduled neighborhood locations",
#         "coordinate bakery deliveries",
#         "site preparation",
#         "related occupations coordinate training activities",
#         "coordinate office services",
#         "specific body area",
#         "coordinate health needs assessments",
#         "replace damaged parts",
#         "local area",
#         "conduct site audits",
#         "coordinate equipment purchases",
#         "workplace application",
#         "coordinate furnishing fabrics",
#         "real estate",
#         "test workplaces",
#         "coordinate installation",
#         "replacement safe",
#         "maintain clean work areas",
#         "district policies",
#         "visit proposed installation sites",
#         "replace machine parts",
#         "plated areas",
#         "produce electricity",
#         "pat areas",
#         "order placement",
#         "statements",
#         "organize work area",
#         "prepare statements",
#         "paint areas",
#         "proportional point locations based",
#         "evaluate workplace environments",
#         "survey land",
#         "survey meters",
#         "demonstration areas",
#         "delivery route",
#         "visit site",
#         "replacements",
#         "replace structural frame members",
#         "earning capacity",
#         "coordinate placement",
#         "designated locations",
#         "new addresses",
#         "cooking area",
#         "corporate financial statements",
#         "check survey responses",
#         "place children",
#         "clean work areas",
#         "route incoming mail",
#         "temporary working areas",
#         "place semiconductor wafers",
#         "placement programs",
#         "place tires",
#         "prepare patient treatment areas",
#         "including landing gear",
#         "blood flow velocity measurements",
#         "cochlear implant mapping",
#         "coordinate corrections",
#         "coordinate grant applications",
#         "occupational therapy work area",
#         "replace tank car dome caps",
#         "coordinate shipping activities",
#         "address business",
#         "existing store locations",
#         "replace defective components",
#         "bank statements",
#         "surveyors",
#         "replace dull cutting tools",
#         "equipment replaced",
#         "topographical maps",
#         "replacement parts",
#         "place products",
#         "state laws permit",
#         "project sites",
#         "defective areas",
#         "adding replacement parts",
#         "monitor cargo area conditions",
#         "place original copies",
#         "compare shipping routes",
#         "address problems related",
#         "route written",
#         "factory processing areas",
#         "coordinated",
#         "hole locations",
#         "disinfect incision sites",
#         "place items",
#         "regional councils",
#         "specified location",
#         "determine routes",
#         "survey employees",
#         "coordinate transfer",
#         "coordinate operational activities",
#         "place containers",
#         "replace worn tools",
#         "related occupations maintain equipment storage areas",
#         "coordinate special products",
#         "equipment replacement parts",
#         "expenditure statements",
#         "coordinate disbursement",
#         "salivary glands",
#         "place coated workpieces",
#         "replace toxic materials",
#         "route correspondence",
#         "route mail",
#         "coordinate web",
#         "ensure appropriate placement",
#         "coordinate safety",
#         "coordinate special events",
#         "keep areas neat",
#         "coordinate treatment plans",
#         "simplicity",
#         "coordinate warehouse activities",
#         "place materials",
#         "measure velocity",
#         "coordinate user",
#         "approve reinstatement",
#         "route statements",
#         "shopping areas",
#         "maintain massage areas",
#         "replace worn",
#         "coordinate design activities",
#         "address areas",
#         "coordinate completion",
#         "particular location",
#         "parasite",
#         "state legal regulations",
#         "disaster site triage centers",
#         "assigned areas",
#         "place parts",
#         "best sites",
#         "appropriate location",
#         "coordinate recruitment",
#         "relocation assistance",
#         "specific drug therapy areas",
#         "state",
#         "surfaces near work areas",
#         "composite products",
#         "coordinate educational programs",
#         "rural electric",
#         "land",
#         "reactions take place",
#         "address performance problems",
#         "related occupations keep storage areas",
#         "target area",
#         "coordinate diet counseling services",
#         "maintain work area",
#         "using portable routers",
#         "coordinate client",
#         "treatment areas",
#         "study maps",
#         "sending financial statements",
#         "coordinate patient care",
#         "direct case service allocations",
#         "cutting areas",
#         "replace faulty components",
#         "obtain maps",
#         "coordinate sales promotion activities",
#         "place workpieces",
#         "survey forms",
#         "cleaning work areas",
#         "coordinate vehicle movement",
#         "land titles act",
#         "specified areas",
#         "replace depleted supply packages",
#         "hazardous waste sites",
#         "replace soiled linens",
#         "route materials",
#         "treat patients en route",
#         "route messages",
#         "manage regional anesthetic techniques",
#         "green building sites",
#         "procure replacement parts",
#         "workplace",
#         "correct locations following demonstrations",
#         "mark defective areas",
#         "coordinate",
#         "local population surveys",
#         "machining locations",
#         "addressing patient needs",
#         "including equipment placement",
#         "living areas clean",
#         "coordinate activities concerned",
#         "identify toxicity",
#         "outplacement",
#         "behavioral states",
#         "installation site",
#         "coordinate work activities",
#         "using compasses",
#         "addressed",
#         "nerve conduction velocity tests",
#         "relocation",
#         "appropriate resource allocation",
#         "replace specified parts",
#         "coordinate occupational therapy",
#         "visit beta testing sites",
#         "public health surveys",
#         "address patient needs",
#         "allocation",
#         "polish engraved areas",
#         "replace damaged molds",
#         "coordinate marketing activities",
#         "site job coaching",
#         "coordinate therapists",
#         "plan locations",
#         "route items",
#         "address community health issues",
#         "financial statements",
#         "specified work areas",
#         "felling sites",
#         "replace loose jewels",
#         "locations",
#         "replacement",
#         "replace defective parts",
#         "state government",
#         "replace defective",
#         "reinstated",
#         "patient areas",
#         "compasses",
#         "place dough",
#         "replace electrical accessories",
#         "evaluate recreation areas",
#         "replace handles",
#         "address legal issues",
#         "storage areas",
#         "perform cesarean sections",
#         "sites",
#         "collection sites",
#         "determine locations",
#         "restock storage areas",
#         "reducing routes",
#         "conduct surveys",
#         "coordinate activities involving sales",
#         "monitor work areas",
#         "machine capacity",
#         "designated areas",
#         "policy reinstatement",
#         "coordinate sales campaigns",
#         "workplaces",
#         "displaced individuals",
#         "replace worn parts",
#         "survey",
#         "coordinate construction",
#         "workplace incidents",
#         "rotten areas",
#         "landscapes",
#         "addressed correctly",
#         "surveyed",
#         "address complaints",
#         "storage locations",
#         "areas",
#         "replace saw blades",
#         "related occupations place products",
#         "coordinate survey work",
#         "place workpieces onto machine feed carriages",
#         "specified hospital locations",
#         "recycling collection sites",
#         "shape replacement body sections",
#         "coordinate special programs",
#         "design area layout",
#         "place incoming",
#         "parasite tests",
#         "web sites",
#         "replace soles",
#         "replace webbing",
#         "work area",
#         "coordinate investigation",
#         "weigh envelopes containing statements",
#         "coordinate recipe development",
#         "coolant onto work areas",
#         "place identifying tags",
#         "inaccessible work sites",
#         "coordinate fitting",
#         "operative area",
#         "coordinate material handling",
#         "coordinate orthodontic services",
#         "place acceptable products",
#         "estate planning",
#         "cutting locations",
#         "replace defective pressure vessel parts",
#         "industrial sites",
#         "routers",
#         "lung capacity tests"
#     ]
# }
